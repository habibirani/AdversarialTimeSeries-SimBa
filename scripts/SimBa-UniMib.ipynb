# %%
import os
import shutil
from scipy import io #for loadmat, matlab conversion
import numpy as np
import matplotlib.pyplot as plt # for plotting training curves
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import requests #for downloading zip file
from torch.utils.data import DataLoader, TensorDataset
#imports for computing and displaying output metrics
import urllib.request # to get files from web w/o !wget

# temp - needed for SHL split
from sklearn.model_selection import train_test_split

# %%
def namestr(obj, namespace):
    return [name for name in namespace if namespace[name] is obj]

def get_shapes(np_arr_list):
    """Returns text, each line is shape and dtype for numpy array in list
       example: print(get_shapes([X_train, X_test, y_train, y_test]))"""
    shapes = ""
    for i in np_arr_list:
        my_name = namestr(i,globals())
        shapes += (my_name[0] + " shape is " + str(i.shape) \
            + " data type is " + str(i.dtype) + "\n")
    return shapes

# %%
def get_py_file(fname, url):
    """checks for local file, if none downloads from URL.
    :return: nothing"""
    if (os.path.exists(fname)):
        print ("Local",fname, "found, skipping download")
    else:
        print("Downloading",fname, "from IMICS git repo")
        urllib.request.urlretrieve(url, filename=fname)

get_py_file(fname = 'load_data_utils.py', url = 'https://raw.githubusercontent.com/imics-lab/load_data_time_series/main/load_data_utils.py')
# Out:
# Downloading load_data_utils.py from IMICS git repo

# %%
import load_data_utils as utils # ldu just seemed confusing!
print('My env_info: \n' + utils.get_env_info()) # using + vs , gets rid of space
# Out:
# My env_info:
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# GPU:

# %%
def get_dataset(dataset):
    if (dataset == 'MobiAct HAR'):
        if (os.path.exists('MobiAct_Dataset_v1.0.zip')):
            print ("Local MobiAct zip found, skipping download")
        else:
            # !gdown "1kt9wtIt7N7SIFQAbav7zcZ_PqTa5HegA&confirm=t" # MobiAct alternate file source
        # original share is https://drive.google.com/uc?id=0B5VcW5yHhWhibWxGRTZDd0dGY2s'
        # please see https://bmi.hmu.gr/the-mobifall-and-mobiact-datasets-2/ if not working
        get_py_file(fname = 'mobiact_adl_load_dataset.py',
                url = 'https://raw.githubusercontent.com/imics-lab/load_data_time_series/main/HAR/MobiAct/mobiact_adl_load_dataset.py')
        from mobiact_adl_load_dataset import mobiact_adl_load_dataset
        x_train, y_train, x_valid, y_valid, x_test, y_test = mobiact_adl_load_dataset(incl_val_group = True)
        k_size = 50
        EPOCHS = 50
        t_names = ['JOG','JUM','STD','STN','STU','WAL']
    elif (dataset == 'UniMiB SHAR'):
        get_py_file(fname = 'unimib_adl_load_dataset.py',
                url = 'https://raw.githubusercontent.com/imics-lab/load_data_time_series/main/HAR/UniMiB_SHAR/unimib_shar_adl_load_dataset.py')
        from unimib_adl_load_dataset import unimib_load_dataset
        x_train, y_train, x_valid, y_valid, x_test, y_test = unimib_load_dataset(incl_val_group = True)
        t_names = ['StandingUpFS','StandingUpFL','Walking','Running','GoingUpS','Jumping','GoingDownS','LyingDownFS','SittingDown']
        k_size = 50
        EPOCHS = 2
    elif (dataset == 'UCI HAR'):
        get_py_file(fname = 'uci_har_load_dataset.py',
                    url = 'https://raw.githubusercontent.com/imics-lab/load_data_time_series/main/HAR/UCI_HAR/uci_har_load_dataset.py')
        from uci_har_load_dataset import uci_har_load_dataset
        x_train, y_train, x_valid, y_valid, x_test, y_test = uci_har_load_dataset(incl_val_group = True, incl_xyz_accel= True)
        t_names = ['WALKING','WALKING_UPSTAIRS','WALKING_DOWNSTAIRS','SITTING','STANDING','LAYING']
        k_size = 50
        EPOCHS = 30
    elif (dataset == 'TWristAR'):
        # Note TWristAR is more updated than the previous datasets so the accesses
        # and defaults are a bit different, e.g. t_names is pulled from the .py
        get_py_file(fname = 'twristar_load_dataset.py',
                    url = 'https://raw.githubusercontent.com/imics-lab/load_data_time_series/main/HAR/TWristAR/twristar_load_dataset.py')
        import twristar_load_dataset as twristar_load_dataset # diff to get label map
        x_train, y_train, x_valid, y_valid, x_test, y_test \
                                = twristar_load_dataset.twristar_load_dataset(
                                    incl_val_group = True,
                                    one_hot_encode = True)
        t_names = list(twristar_load_dataset.label_map_twristar.get('label').keys())
        t_names.remove('Undefined')
        k_size = 16
        EPOCHS = 20
    elif (dataset == 'Leotta_2021'):
        get_py_file(fname = 'leotta_2021_load_dataset.py',
                    url = 'https://raw.githubusercontent.com/imics-lab/load_data_time_series/main/ADL/Leotta_2021/leotta_2021_load_dataset.py')
        #full_filename = my_path+os.path.join('/ADL/Leotta_2021/'+'leotta_2021_load_dataset.py')
        #shutil.copy(full_filename,'leotta_2021_load_dataset.py')

        import leotta_2021_load_dataset as leotta_2021_load_dataset
        x_train, y_train, x_valid, y_valid, x_test, y_test = leotta_2021_load_dataset.leotta_2021_load_dataset(incl_val_group = True, one_hot_encode = True)
        t_names = list(leotta_2021_load_dataset.label_map_leotta.get('label').keys())
        k_size = 100
        EPOCHS = 50
    elif (dataset == 'SHL'):
        # SHL takes about 30 minutes to process due to size, using saved arrays for now
        # !gdown "1ApHVQ-P2reO6ctNVxeHHxCHeoNlp6c9P&confirm=t" # SHL 20Hz
        utils.unzip_into_dir('SHL_20hz_for_gentry.zip','SHL')
        input_dir = './SHL'
        x_train = np.load(input_dir + '/'+'x_train.npy')
        x_train = np.delete(x_train, [0,1,2], 2) # delete component accel
        x_test = np.load(input_dir + '/'+'x_test.npy')
        x_test = np.delete(x_test, [0,1,2], 2) # delete component accel
        y_train = np.load(input_dir + '/'+'y_train.npy')
        y_test = np.load(input_dir + '/'+'y_test.npy')
        # also don't have validate working in SHL so just using stratify
        x_train, x_valid, y_train, y_valid = train_test_split(x_train, y_train, test_size=0.10, random_state=42, stratify=y_train)

        t_names = ['Still', 'Walking', 'Run', 'Bike', 'Car', 'Bus', 'Train', 'Subway']
        k_size = 15
        EPOCHS = 100
    elif (dataset == 'Gesture Phase Segmentation'):
        get_py_file(fname = 'gesture_phase_segmentation_load_dataset.py',
                    url = 'https://raw.githubusercontent.com/imics-lab/load_data_time_series/main/Gesturing_Signing/gesture_phase_segmentation_load_dataset.py')
        from gesture_phase_segmentation_load_dataset import gesture_phase_segmentation_load_dataset
        x_train, y_train, x_valid, y_valid, x_test, y_test, log_info \
                                = gesture_phase_segmentation_load_dataset(
                                    incl_val_group = True,
                                    return_info_dict = True)
        print("Note: Due to the size of the Gesture Phase Segmentation and for",
            "\ncompatibility, the test arrays are copies of the valid arrays")
        x_test = x_valid.copy()
        y_test = y_valid.copy()
        t_names = ["Rest", "Preparation", "Stroke","Hold", "Retraction"]
        k_size = 9
        EPOCHS = 30
    else:
        print('ERROR: dataset unknown')
    print(utils.tabulate_numpy_arrays({'x_train':x_train,'y_train':y_train,
                                    'x_valid':x_valid,'y_valid':y_valid,
                                    'x_test':x_test,'y_test':y_test}))
    return x_train, y_train, x_valid, y_valid, x_test, y_test, k_size, EPOCHS, t_names

# %%
ds_list = ["UniMiB SHAR",
           "UCI HAR",
           "TWristAR",
           "Gesture Phase Segmentation"
           ]

# %%
# Setting up the device for Torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
#credit https://stackoverflow.com/questions/9419162/download-returned-zip-file-from-url
#many other methods I tried failed to download the file properly
def download_url(url, save_path, chunk_size=128):
    r = requests.get(url, stream=True)
    with open(save_path, 'wb') as fd:
        for chunk in r.iter_content(chunk_size=chunk_size):
            fd.write(chunk)

def unimib_load_dataset(
    verbose = True,
    incl_xyz_accel = False, #include component accel_x/y/z in ____X data
    incl_rms_accel = True, #add rms value (total accel) of accel_x/y/z in ____X data
    incl_val_group = False, #True => returns x/y_test, x/y_validation, x/y_train
                           #False => combine test & validation groups
    split_subj = dict
                (train_subj = [4,5,6,7,8,10,11,12,14,15,19,20,21,22,24,26,27,29],
                validation_subj = [1,9,16,23,25,28],
                test_subj = [2,3,13,17,18,30]),
    one_hot_encode = True):

    #Download and unzip original dataset
    if (not os.path.isfile('./UniMiB-SHAR.zip')):
        print("Downloading UniMiB-SHAR.zip file")
        #invoking the shell command fails when exported to .py file
        #redirect link https://www.dropbox.com/s/raw/x2fpfqj0bpf8ep6/UniMiB-SHAR.zip
        #!wget https://www.dropbox.com/s/x2fpfqj0bpf8ep6/UniMiB-SHAR.zip
        download_url('https://www.dropbox.com/s/raw/x2fpfqj0bpf8ep6/UniMiB-SHAR.zip','./UniMiB-SHAR.zip')
    if (not os.path.isdir('./UniMiB-SHAR')):
        shutil.unpack_archive('./UniMiB-SHAR.zip','.','zip')
    #Convert .mat files to numpy ndarrays
    path_in = './UniMiB-SHAR/data'
    #loadmat loads matlab files as dictionary, keys: header, version, globals, data
    adl_data = io.loadmat(path_in + '/adl_data.mat')['adl_data']
    adl_names = io.loadmat(path_in + '/adl_names.mat', chars_as_strings=True)['adl_names']
    adl_labels = io.loadmat(path_in + '/adl_labels.mat')['adl_labels']

    #Reshape data and compute total (rms) acceleration
    num_samples = 151
    #UniMiB SHAR has fixed size of 453 which is 151 accelX, 151 accely, 151 accelz
    adl_data = np.reshape(adl_data,(-1,num_samples,3), order='F') #uses Fortran order
    if (incl_rms_accel):
        rms_accel = np.sqrt((adl_data[:,:,0]**2) + (adl_data[:,:,1]**2) + (adl_data[:,:,2]**2))
        adl_data = np.dstack((adl_data,rms_accel))

    #remove component accel if needed
    if (not incl_xyz_accel):
        adl_data = np.delete(adl_data, [0,1,2], 2)

    act_num = (adl_labels[:,0])-1 #matlab source was 1 indexed, change to 0 indexed
    sub_num = (adl_labels[:,1]) #subject numbers are in column 1 of labels

    if (not incl_val_group):
        train_index = np.nonzero(np.isin(sub_num, split_subj['train_subj'] +
                                        split_subj['validation_subj']))
        x_train = adl_data[train_index]
        y_train = act_num[train_index]
    else:
        train_index = np.nonzero(np.isin(sub_num, split_subj['train_subj']))
        x_train = adl_data[train_index]
        y_train = act_num[train_index]

        validation_index = np.nonzero(np.isin(sub_num, split_subj['validation_subj']))
        x_validation = adl_data[validation_index]
        y_validation = act_num[validation_index]

    test_index = np.nonzero(np.isin(sub_num, split_subj['test_subj']))
    x_test = adl_data[test_index]
    y_test = act_num[test_index]

    if (verbose):
        print("x/y_train shape ",x_train.shape,y_train.shape)
    if (incl_val_group):
        print("x/y_validation shape ",x_validation.shape,y_validation.shape)
    print("x/y_test shape  ",x_test.shape,y_test.shape)

    if (incl_val_group):
        return x_train, y_train, x_validation, y_validation, x_test, y_test
    else:
        return x_train, y_train, x_test, y_test

# %%
X_train, y_train, X_valid, y_valid, X_test, y_test = unimib_load_dataset(
    incl_xyz_accel=True, incl_val_group=True, one_hot_encode=False, verbose=True)

# Number of classes
n_classes = len(np.unique(y_train))
print(f"Number of classes: {n_classes}")
# Out:
# Downloading UniMiB-SHAR.zip file
# x/y_train shape  (4601, 151, 4) (4601,)
# x/y_validation shape  (1454, 151, 4) (1454,)
# x/y_test shape   (1524, 151, 4) (1524,)
# Number of classes: 9

# %%
X_train = torch.tensor(X_train, dtype=torch.float32)
Y_train = torch.tensor(y_train, dtype=torch.int64)

X_valid = torch.tensor(X_valid, dtype=torch.float32)
Y_valid = torch.tensor(y_valid, dtype=torch.int64)

X_test = torch.tensor(X_test, dtype=torch.float32)
Y_test = torch.tensor(y_test, dtype=torch.int64)

# Swap channel and time dimensions for compatibility with PyTorch Conv1D
X_train = X_train.permute(0, 2, 1)
X_valid = X_valid.permute(0, 2, 1)
X_test = X_test.permute(0, 2, 1)

# DataLoaders
batch_size = 64
train_dataset = TensorDataset(X_train, Y_train)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, drop_last=True)

valid_dataset = TensorDataset(X_valid, Y_valid)
valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False, drop_last=True)

test_dataset = TensorDataset(X_test, Y_test)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, drop_last=True)

# %%
# Model hyperparameters
n_features = 4  # Number of input features/channels
WINDOW_SIZE = 151  # Number of timesteps in each sequence
n_outputs = n_classes  # Number of output classes or nodes in the last layer
num_filters = 100  # Number of filters in Conv layers
kernel_size = 9  # Kernel size for Conv layers
pool_size = 2  # Pool size for MaxPooling
dropout_rate = 0.5  # Dropout rate
fc1_output_size = 128  # Output size of the first Dense layer, adjustable


# Define the CNN model
class CNN1D(nn.Module):
    def __init__(self, n_features=3, WINDOW_SIZE=35, n_outputs=1, num_filters=64, kernel_size=3, pool_size=2, dropout_rate=0.5, fc1_output_size=128):
        super(CNN1D, self).__init__()
        self.conv1 = nn.Conv1d(n_features, num_filters,
                               kernel_size=kernel_size, padding=1)
        self.bn1 = nn.BatchNorm1d(num_filters)
        self.conv2 = nn.Conv1d(num_filters, num_filters,
                               kernel_size=kernel_size, padding=1)
        self.pool = nn.MaxPool1d(pool_size)
        self.dropout = nn.Dropout(dropout_rate)

        # Dynamically compute the size of the input to the first fully connected layer
        self.fc1_input_size = self._get_conv_output(WINDOW_SIZE)
        self.fc1 = nn.Linear(self.fc1_input_size, fc1_output_size)
        self.fc2 = nn.Linear(fc1_output_size, n_outputs)

    def _get_conv_output(self, size):
        with torch.no_grad():
            # Dummy input to calculate convolution output size
            dummy_input = torch.zeros(1, n_features, size)
            output = self.conv1(dummy_input)
            output = self.conv2(output)
            output = self.pool(output)
            return np.prod(output.size()[1:])  # total number of features

    def forward(self, x):
        x = F.relu(self.bn1(self.conv1(x)))
        x = F.relu(self.conv2(x))
        x = self.dropout(self.pool(x))
        x = x.view(-1, self.fc1_input_size)  # flatten the tensor
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# Instantiate the model
model = CNN1D(n_features=n_features, WINDOW_SIZE=WINDOW_SIZE, n_outputs=n_outputs, num_filters=num_filters,
              kernel_size=kernel_size, pool_size=pool_size, dropout_rate=dropout_rate, fc1_output_size=fc1_output_size)
print(model)
# Out:
# CNN1D(
#   (conv1): Conv1d(4, 100, kernel_size=(9,), stride=(1,), padding=(1,))
#   (bn1): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv1d(100, 100, kernel_size=(9,), stride=(1,), padding=(1,))
#   (pool): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc1): Linear(in_features=6900, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=9, bias=True)
# )

# %%
# Model, loss function, and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters())

# Number of epochs
n_epochs = 2

for epoch in range(n_epochs):
    model.train()  # Set model to training mode
    train_losses = []
    train_correct = 0
    total = 0

    # Training loop
    for inputs, labels in train_loader:
        optimizer.zero_grad()  # Zero the parameter gradients

        predictions = model(inputs)  # Forward pass
        loss = criterion(predictions, labels)  # Calculate loss

        loss.backward()  # Backward pass
        optimizer.step()  # Optimize

        train_losses.append(loss.item())

        # Convert probabilities to binary predictions
        train_correct += (predictions.argmax(1) == labels).sum().item()  # Count the number of correct predictions
        total += labels.size(0)

    train_loss = np.mean(train_losses)
    train_acc = train_correct / total

    # Validation loop (optional, remove if not needed)
    model.eval()  # Set model to evaluation mode
    with torch.no_grad():
        validation_losses = []
        validation_correct = 0
        total_val = 0

        for inputs, labels in valid_loader:
            predictions = model(inputs)
            loss = criterion(predictions, labels)
            validation_losses.append(loss.item())

            validation_correct += (predictions.argmax(1) == labels).sum().item()
            total_val += labels.size(0)

        validation_loss = np.mean(validation_losses)
        validation_acc = validation_correct / total_val

    print(f'Epoch {epoch+1}, Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}, Val Loss: {validation_loss:.4f}, Val Acc: {validation_acc:.4f}')
# Out:
# Epoch 1, Train Loss: 0.9540, Train Acc: 0.6525, Val Loss: 0.7778, Val Acc: 0.7244
# Epoch 2, Train Loss: 0.4080, Train Acc: 0.8435, Val Loss: 0.4543, Val Acc: 0.8374

# %%
# Setting up the device for Torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


def simba_single(model, x, y, num_iters=1000, epsilon=0.1, targeted=False):
    x = x.clone().detach().to(device)  # Ensure that x is a copy and moved to the correct device
    y = y.to(device)
    batch_size, seq_len, num_features = x.shape
    n_dims = seq_len * num_features  # Total dimensions in a flattened time series per sample

    perm = torch.randperm(n_dims).to(device)  # Random permutation of indices within a time step and features
    last_prob = get_probs(model, x, y)

    for i in range(num_iters):
        index = perm[i % n_dims]  # Ensure we do not go out of bounds
        feature_index = index % num_features  # Feature index
        time_step_index = index // num_features  # Time step index

        diff = torch.zeros_like(x)
        diff[:, time_step_index, feature_index] = epsilon

        # Test perturbation in the negative direction
        neg_x = (x - diff).clamp(0, 1)
        neg_prob = get_probs(model, neg_x, y)

        # Test perturbation in the positive direction
        pos_x = (x + diff).clamp(0, 1)
        pos_prob = get_probs(model, pos_x, y)

        # Decide which direction to keep based on the probability change
        if targeted:  # For targeted attacks, we want to increase the probability of the target class
            improved = pos_prob > neg_prob
        else:  # For untargeted attacks, we want to decrease the probability of the correct class
            improved = neg_prob < pos_prob

        if improved.any():
            x = pos_x if targeted else neg_x
            last_prob = pos_prob if targeted else neg_prob

        # Optional: print progress
        if i % 100 == 0:
            print(f'Iteration {i}: Probability = {last_prob.mean().item()}')

    return x



# Helper functions
def normalize(time_series):
    min_val = torch.min(time_series)
    max_val = torch.max(time_series)
    return (time_series - min_val) / (max_val - min_val)

def get_probs(model, time_series, labels):
    time_series = normalize(time_series)
    output = model(time_series)
    probs = F.softmax(output, dim=1)
    target_probs = probs.gather(1, labels.view(-1, 1)).squeeze()
    return target_probs

# Create dataset and DataLoader
data, labels = create_dataset()
dataset = TensorDataset(data, labels)
loader = DataLoader(dataset, batch_size=10)

# Initialize and train the model
model = CNN1D().to(device)
optimizer = optim.Adam(model.parameters(), lr=0.01)
loss_function = nn.CrossEntropyLoss()

# Training loop
for epoch in range(5):  # Train for 5 epochs
    for inputs, targets in loader:
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = loss_function(outputs, targets)
        loss.backward()
        optimizer.step()
    print(f'Epoch {epoch+1}, Loss: {loss.item()}')

# Evaluate using SimBA
model.eval()
success_count = 0
total_count = 0

for inputs, targets in loader:
    inputs, targets = inputs.to(device), targets.to(device)
    adv_inputs = simba_single(model, inputs, targets)
    adv_preds = model(adv_inputs).argmax(dim=1)
    success_count += (adv_preds != targets).sum().item()
    total_count += targets.size(0)

success_rate = (success_count / total_count) * 100
print(f'Success rate of SimBA attack: {success_rate}%')
# Out:
# Epoch 1, Loss: 0.7178683876991272
# Epoch 2, Loss: 0.7059564590454102
# Epoch 3, Loss: 0.6993428468704224
# Epoch 4, Loss: 0.696172297000885
# Epoch 5, Loss: 0.6940113306045532
# Iteration 0: Probability = 0.5206619501113892
# Iteration 100: Probability = 0.5176768898963928
# Iteration 200: Probability = 0.5153553485870361
# Iteration 300: Probability = 0.5134428143501282
# Iteration 400: Probability = 0.5119160413742065
# Iteration 500: Probability = 0.510849118232727
# Iteration 600: Probability = 0.510849118232727
# Iteration 700: Probability = 0.510849118232727
# Iteration 800: Probability = 0.510849118232727
# Iteration 900: Probability = 0.510849118232727
# Iteration 0: Probability = 0.5034932494163513
# Iteration 100: Probability = 0.5028680562973022
# Iteration 200: Probability = 0.5023038983345032
# Iteration 300: Probability = 0.5013421773910522
# Iteration 400: Probability = 0.5005431175231934
# Iteration 500: Probability = 0.5
# Iteration 600: Probability = 0.5
# Iteration 700: Probability = 0.5
# Iteration 800: Probability = 0.5
# Iteration 900: Probability = 0.5
# Iteration 0: Probability = 0.4908304214477539
# Iteration 100: Probability = 0.49237436056137085
# Iteration 200: Probability = 0.49373722076416016
# Iteration 300: Probability = 0.49473491311073303
# Iteration 400: Probability = 0.4955102801322937
# Iteration 500: Probability = 0.4962734282016754
# Iteration 600: Probability = 0.49638357758522034
# Iteration 700: Probability = 0.49638357758522034
# Iteration 800: Probability = 0.49638357758522034
# Iteration 900: Probability = 0.49638357758522034
# Iteration 0: Probability = 0.5169702172279358
# Iteration 100: Probability = 0.5130404233932495
# Iteration 200: Probability = 0.5110185146331787
# Iteration 300: Probability = 0.509566605091095
# Iteration 400: Probability = 0.5081459879875183
# Iteration 500: Probability = 0.5072331428527832
# Iteration 600: Probability = 0.5072327852249146
# Iteration 700: Probability = 0.5072327852249146
# Iteration 800: Probability = 0.5072327852249146
# Iteration 900: Probability = 0.5072327852249146
# Iteration 0: Probability = 0.48552393913269043
# Iteration 100: Probability = 0.4902305006980896
# Iteration 200: Probability = 0.49124908447265625
# Iteration 300: Probability = 0.4918832778930664
# Iteration 400: Probability = 0.4924018979072571
# Iteration 500: Probability = 0.49276065826416016
# Iteration 600: Probability = 0.49276724457740784
# Iteration 700: Probability = 0.49276724457740784
# Iteration 800: Probability = 0.49276724457740784
# Iteration 900: Probability = 0.49276724457740784
# Iteration 0: Probability = 0.512589693069458
# Iteration 100: Probability = 0.5112001895904541
# Iteration 200: Probability = 0.5098546743392944
# Iteration 300: Probability = 0.5087250471115112
# Iteration 400: Probability = 0.5078519582748413
# Iteration 500: Probability = 0.5072327852249146
# Iteration 600: Probability = 0.5072327852249146
# Iteration 700: Probability = 0.5072327852249146
# Iteration 800: Probability = 0.5072327852249146
# Iteration 900: Probability = 0.5072327852249146
# Iteration 0: Probability = 0.5067564249038696
# Iteration 100: Probability = 0.5047473907470703
# Iteration 200: Probability = 0.5043824911117554
# Iteration 300: Probability = 0.503861129283905
# Iteration 400: Probability = 0.5036146640777588
# Iteration 500: Probability = 0.503616452217102
# Iteration 600: Probability = 0.503616452217102
# Iteration 700: Probability = 0.503616452217102
# Iteration 800: Probability = 0.503616452217102
# Iteration 900: Probability = 0.503616452217102
# Iteration 0: Probability = 0.5142050981521606
# Iteration 100: Probability = 0.5113117098808289
# Iteration 200: Probability = 0.5100731253623962
# Iteration 300: Probability = 0.5089749693870544
# Iteration 400: Probability = 0.5079545378684998
# Iteration 500: Probability = 0.5072348713874817
# Iteration 600: Probability = 0.5072327852249146
# Iteration 700: Probability = 0.5072327852249146
# Iteration 800: Probability = 0.5072327852249146
# Iteration 900: Probability = 0.5072327852249146
# Iteration 0: Probability = 0.4755523204803467
# Iteration 100: Probability = 0.47830528020858765
# Iteration 200: Probability = 0.48046427965164185
# Iteration 300: Probability = 0.4822467863559723
# Iteration 400: Probability = 0.4839804172515869
# Iteration 500: Probability = 0.48553451895713806
# Iteration 600: Probability = 0.4855344891548157
# Iteration 700: Probability = 0.4855344891548157
# Iteration 800: Probability = 0.4855344891548157
# Iteration 900: Probability = 0.4855344891548157
# Iteration 0: Probability = 0.49290770292282104
# Iteration 100: Probability = 0.49708613753318787
# Iteration 200: Probability = 0.49700459837913513
# Iteration 300: Probability = 0.49693116545677185
# Iteration 400: Probability = 0.49672093987464905
# Iteration 500: Probability = 0.4963836669921875
# Iteration 600: Probability = 0.4963836669921875
# Iteration 700: Probability = 0.4963836669921875
# Iteration 800: Probability = 0.4963836669921875
# Iteration 900: Probability = 0.4963836669921875
# Success rate of SimBA attack: 48.0%

# %%
# Define function to train your model
def train_model(model, train_loader, optimizer, criterion, device, num_epochs):
    # Training loop
    for epoch in range(num_epochs):
        model.train()
        # Iterate over batches of data
        for inputs, targets in train_loader:
            inputs, targets = inputs.to(device), targets.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            loss.backward()
            optimizer.step()
        print(f'Epoch {epoch+1}, Loss: {loss.item()}')


# Initialize the model
n_features = 4  # Number of input features/channels
WINDOW_SIZE = 151  # Number of timesteps in each sequence
n_outputs = 9  # Number of output classes or nodes in the last layer
num_filters = 100  # Number of filters in Conv layers
kernel_size = 9  # Kernel size for Conv layers
pool_size = 2  # Pool size for MaxPooling
dropout_rate = 0.5  # Dropout rate
fc1_output_size = 128  # Output size of the first Dense layer, adjustable

model = CNN1D(n_features=n_features, WINDOW_SIZE=WINDOW_SIZE, n_outputs=n_outputs,
              num_filters=num_filters, kernel_size=kernel_size, pool_size=pool_size,
              dropout_rate=dropout_rate, fc1_output_size=fc1_output_size)
print(model)

# Create dataset and DataLoader
data, labels = train_dataset()
dataset = TensorDataset(data, labels)
loader = DataLoader(dataset, batch_size=10)

# Initialize and train the model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)
optimizer = optim.Adam(model.parameters(), lr=0.01)
criterion = nn.CrossEntropyLoss()

# Training loop
train_model(model, loader, optimizer, criterion, device, num_epochs=5)

# Evaluate using SimBA
model.eval()
success_count = 0
total_count = 0

for inputs, targets in loader:
    inputs, targets = inputs.to(device), targets.to(device)
    adv_inputs = simba_single(model, inputs, targets)
    adv_preds = model(adv_inputs).argmax(dim=1)
    success_count += (adv_preds != targets).sum().item()
    total_count += targets.size(0)

success_rate = (success_count / total_count) * 100
print(f'Success rate of SimBA attack: {success_rate}%')

# Function to evaluate performance
def evaluate_performance(model, loader):
    model.eval()
    clean_correct = 0
    adv_correct = 0
    total = 0

    for inputs, targets in loader:
        inputs, targets = inputs.to(device), targets.to(device)
        clean_outputs = model(inputs)
        clean_preds = clean_outputs.argmax(dim=1)
        clean_correct += (clean_preds == targets).sum().item()

        adv_inputs = simba_single(model, inputs, targets)
        adv_outputs = model(adv_inputs)
        adv_preds = adv_outputs.argmax(dim=1)
        adv_correct += (adv_preds == targets).sum().item()

        total += targets.size(0)

    clean_accuracy = 100 * clean_correct / total
    adv_accuracy = 100 * adv_correct / total

    return clean_accuracy, adv_accuracy

# Evaluate performance before and after adversarial training
clean_acc_before, adv_acc_before = evaluate_performance(model, loader)
print(f'Before Adversarial Training - Clean Acc: {clean_acc_before}%, Adversarial Acc: {adv_acc_before}%')

# Assuming you have adversarially trained the model here

clean_acc_after, adv_acc_after = evaluate_performance(model, loader)
print(f'After Adversarial Training - Clean Acc: {clean_acc_after}%, Adversarial Acc: {adv_acc_after}%')
# Out:
# CNN1D(
#   (conv1): Conv1d(4, 100, kernel_size=(9,), stride=(1,), padding=(1,))
#   (bn1): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv1d(100, 100, kernel_size=(9,), stride=(1,), padding=(1,))
#   (pool): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc1): Linear(in_features=6900, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=9, bias=True)
# )
# Epoch 1, Loss: 2.218839645385742
# Epoch 2, Loss: 2.5844833850860596
# Epoch 3, Loss: 2.3791251182556152
# Epoch 4, Loss: 2.18959379196167
# Epoch 5, Loss: 2.2502410411834717
# Iteration 0: Probability = 0.20154409110546112
# Iteration 100: Probability = 0.12873978912830353
# Iteration 200: Probability = 0.12831158936023712
# Iteration 300: Probability = 0.12752056121826172
# Iteration 400: Probability = 0.126000314950943
# Iteration 500: Probability = 0.12676164507865906
# Iteration 600: Probability = 0.12606510519981384
# Iteration 700: Probability = 0.12542851269245148
# Iteration 800: Probability = 0.12516412138938904
# Iteration 900: Probability = 0.12439592182636261
# Iteration 0: Probability = 0.11053629219532013
# Iteration 100: Probability = 0.11066895723342896
# Iteration 200: Probability = 0.1108524352312088
# Iteration 300: Probability = 0.11063208431005478
# Iteration 400: Probability = 0.1104864701628685
# Iteration 500: Probability = 0.11033151298761368
# Iteration 600: Probability = 0.11028505861759186
# Iteration 700: Probability = 0.10993955284357071
# Iteration 800: Probability = 0.11020227521657944
# Iteration 900: Probability = 0.11005432903766632
# Iteration 0: Probability = 0.12075161933898926
# Iteration 100: Probability = 0.12057071924209595
# Iteration 200: Probability = 0.11998070776462555
# Iteration 300: Probability = 0.11960848420858383
# Iteration 400: Probability = 0.11992011219263077
# Iteration 500: Probability = 0.11970464885234833
# Iteration 600: Probability = 0.11845074594020844
# Iteration 700: Probability = 0.11830552667379379
# Iteration 800: Probability = 0.1181316003203392
# Iteration 900: Probability = 0.11763928830623627
# Iteration 0: Probability = 0.18862968683242798
# Iteration 100: Probability = 0.1196359395980835
# Iteration 200: Probability = 0.1187501922249794
# Iteration 300: Probability = 0.11860090494155884
# Iteration 400: Probability = 0.11738412082195282
# Iteration 500: Probability = 0.11788147687911987
# Iteration 600: Probability = 0.11832322180271149
# Iteration 700: Probability = 0.11797282844781876
# Iteration 800: Probability = 0.11700673401355743
# Iteration 900: Probability = 0.11688663810491562
# Iteration 0: Probability = 0.12669628858566284
# Iteration 100: Probability = 0.1256788820028305
# Iteration 200: Probability = 0.12443283945322037
# Iteration 300: Probability = 0.12459132820367813
# Iteration 400: Probability = 0.12398290634155273
# Iteration 500: Probability = 0.12371454387903214
# Iteration 600: Probability = 0.12330055236816406
# Iteration 700: Probability = 0.12288880348205566
# Iteration 800: Probability = 0.12203685939311981
# Iteration 900: Probability = 0.12200312316417694
# Iteration 0: Probability = 0.12247862666845322
# Iteration 100: Probability = 0.12136197090148926
# Iteration 200: Probability = 0.12057159096002579
# Iteration 300: Probability = 0.11975129693746567
# Iteration 400: Probability = 0.12015920877456665
# Iteration 500: Probability = 0.1201338917016983
# Iteration 600: Probability = 0.11954270303249359
# Iteration 700: Probability = 0.11842993646860123
# Iteration 800: Probability = 0.11782707273960114
# Iteration 900: Probability = 0.11719200760126114
# Iteration 0: Probability = 0.11218484491109848
# Iteration 100: Probability = 0.11231379210948944
# Iteration 200: Probability = 0.11199495941400528
# Iteration 300: Probability = 0.11186663806438446
# Iteration 400: Probability = 0.11213193833827972
# Iteration 500: Probability = 0.11207568645477295
# Iteration 600: Probability = 0.111780546605587
# Iteration 700: Probability = 0.11183186620473862
# Iteration 800: Probability = 0.11141245067119598
# Iteration 900: Probability = 0.11140111833810806
# Iteration 0: Probability = 0.11405130475759506
# Iteration 100: Probability = 0.11351541429758072
# Iteration 200: Probability = 0.11248232424259186
# Iteration 300: Probability = 0.11255757510662079
# Iteration 400: Probability = 0.1123676747083664
# Iteration 500: Probability = 0.11249307543039322
# Iteration 600: Probability = 0.11243239790201187
# Iteration 700: Probability = 0.11210215091705322
# Iteration 800: Probability = 0.11132876574993134
# Iteration 900: Probability = 0.11155737936496735
# Iteration 0: Probability = 0.11983989179134369
# Iteration 100: Probability = 0.11935100704431534
# Iteration 200: Probability = 0.11894656717777252
# Iteration 300: Probability = 0.1187991127371788
# Iteration 400: Probability = 0.11852981150150299
# Iteration 500: Probability = 0.11781871318817139
# Iteration 600: Probability = 0.11818262189626694
# Iteration 700: Probability = 0.11818952858448029
# Iteration 800: Probability = 0.11778102070093155
# Iteration 900: Probability = 0.11757870018482208
# Iteration 0: Probability = 0.10760148614645004
# Iteration 100: Probability = 0.10723638534545898
# Iteration 200: Probability = 0.10717101395130157
# Iteration 300: Probability = 0.10686250030994415
# Iteration 400: Probability = 0.10694147646427155
# Iteration 500: Probability = 0.10680921375751495
# Iteration 600: Probability = 0.10648544132709503
# Iteration 700: Probability = 0.10630353540182114
# Iteration 800: Probability = 0.10615529865026474
# Iteration 900: Probability = 0.10617941617965698
# Success rate of SimBA attack: 82.0%
# Iteration 0: Probability = 0.12914690375328064
# Iteration 100: Probability = 0.12948213517665863
# Iteration 200: Probability = 0.12967121601104736
# Iteration 300: Probability = 0.12917976081371307
# Iteration 400: Probability = 0.12839694321155548
# Iteration 500: Probability = 0.1266021579504013
# Iteration 600: Probability = 0.12616942822933197
# Iteration 700: Probability = 0.12639427185058594
# Iteration 800: Probability = 0.12638767063617706
# Iteration 900: Probability = 0.1258624792098999
# Iteration 0: Probability = 0.11113131046295166
# Iteration 100: Probability = 0.1111845001578331
# Iteration 200: Probability = 0.1111118346452713
# Iteration 300: Probability = 0.11084972321987152
# Iteration 400: Probability = 0.11081627756357193
# Iteration 500: Probability = 0.11043472588062286
# Iteration 600: Probability = 0.1104087233543396
# Iteration 700: Probability = 0.1103794127702713
# Iteration 800: Probability = 0.11039324104785919
# Iteration 900: Probability = 0.11027178913354874
# Iteration 0: Probability = 0.12060263007879257
# Iteration 100: Probability = 0.120355024933815
# Iteration 200: Probability = 0.11946582794189453
# Iteration 300: Probability = 0.11872134357690811
# Iteration 400: Probability = 0.11898475885391235
# Iteration 500: Probability = 0.11861542612314224
# Iteration 600: Probability = 0.11861779540777206
# Iteration 700: Probability = 0.11842731386423111
# Iteration 800: Probability = 0.11784466356039047
# Iteration 900: Probability = 0.11730605363845825
# Iteration 0: Probability = 0.18862968683242798
# Iteration 100: Probability = 0.11997856944799423
# Iteration 200: Probability = 0.11929025501012802
# Iteration 300: Probability = 0.11906250566244125
# Iteration 400: Probability = 0.11954349279403687
# Iteration 500: Probability = 0.11890219151973724
# Iteration 600: Probability = 0.11856597661972046
# Iteration 700: Probability = 0.11856202781200409
# Iteration 800: Probability = 0.1178855448961258
# Iteration 900: Probability = 0.11784452199935913
# Iteration 0: Probability = 0.12669673562049866
# Iteration 100: Probability = 0.12519291043281555
# Iteration 200: Probability = 0.125372052192688
# Iteration 300: Probability = 0.12499763816595078
# Iteration 400: Probability = 0.12448127567768097
# Iteration 500: Probability = 0.12432177364826202
# Iteration 600: Probability = 0.1235198974609375
# Iteration 700: Probability = 0.12234000861644745
# Iteration 800: Probability = 0.12244212627410889
# Iteration 900: Probability = 0.12242071330547333
# Iteration 0: Probability = 0.2000124752521515
# Iteration 100: Probability = 0.12265808880329132
# Iteration 200: Probability = 0.12186293303966522
# Iteration 300: Probability = 0.121598020195961
# Iteration 400: Probability = 0.12089933454990387
# Iteration 500: Probability = 0.12047050148248672
# Iteration 600: Probability = 0.11963938176631927
# Iteration 700: Probability = 0.12002171576023102
# Iteration 800: Probability = 0.11966236680746078
# Iteration 900: Probability = 0.11863889545202255
# Iteration 0: Probability = 0.11215802282094955
# Iteration 100: Probability = 0.11163698136806488
# Iteration 200: Probability = 0.1117255911231041
# Iteration 300: Probability = 0.11192955821752548
# Iteration 400: Probability = 0.11178324371576309
# Iteration 500: Probability = 0.11168195307254791
# Iteration 600: Probability = 0.11165821552276611
# Iteration 700: Probability = 0.11133788526058197
# Iteration 800: Probability = 0.11136092245578766
# Iteration 900: Probability = 0.11134611070156097
# Iteration 0: Probability = 0.14021357893943787
# Iteration 100: Probability = 0.11361107975244522
# Iteration 200: Probability = 0.11325603723526001
# Iteration 300: Probability = 0.11279255151748657
# Iteration 400: Probability = 0.11222630739212036
# Iteration 500: Probability = 0.11193428188562393
# Iteration 600: Probability = 0.11211949586868286
# Iteration 700: Probability = 0.11183886229991913
# Iteration 800: Probability = 0.11179518699645996
# Iteration 900: Probability = 0.11165174096822739
# Iteration 0: Probability = 0.11983904987573624
# Iteration 100: Probability = 0.11982153356075287
# Iteration 200: Probability = 0.11909494549036026
# Iteration 300: Probability = 0.11878670752048492
# Iteration 400: Probability = 0.11892036348581314
# Iteration 500: Probability = 0.11836518347263336
# Iteration 600: Probability = 0.11818311363458633
# Iteration 700: Probability = 0.11821851879358292
# Iteration 800: Probability = 0.11777432262897491
# Iteration 900: Probability = 0.11753344535827637
# Iteration 0: Probability = 0.10761741548776627
# Iteration 100: Probability = 0.1075180172920227
# Iteration 200: Probability = 0.10747198760509491
# Iteration 300: Probability = 0.10729598999023438
# Iteration 400: Probability = 0.10717473179101944
# Iteration 500: Probability = 0.1069861426949501
# Iteration 600: Probability = 0.10682837665081024
# Iteration 700: Probability = 0.1070002093911171
# Iteration 800: Probability = 0.1070321649312973
# Iteration 900: Probability = 0.10667379945516586
# Before Adversarial Training - Clean Acc: 30.0%, Adversarial Acc: 19.0%
# Iteration 0: Probability = 0.20154409110546112
# Iteration 100: Probability = 0.12897293269634247
# Iteration 200: Probability = 0.12849360704421997
# Iteration 300: Probability = 0.12732365727424622
# Iteration 400: Probability = 0.12709835171699524
# Iteration 500: Probability = 0.12633660435676575
# Iteration 600: Probability = 0.12613040208816528
# Iteration 700: Probability = 0.12582340836524963
# Iteration 800: Probability = 0.12543049454689026
# Iteration 900: Probability = 0.1243593841791153
# Iteration 0: Probability = 0.11053629219532013
# Iteration 100: Probability = 0.1105613261461258
# Iteration 200: Probability = 0.11059270799160004
# Iteration 300: Probability = 0.11055640131235123
# Iteration 400: Probability = 0.11046483367681503
# Iteration 500: Probability = 0.11027126014232635
# Iteration 600: Probability = 0.11034953594207764
# Iteration 700: Probability = 0.11015329509973526
# Iteration 800: Probability = 0.1101541668176651
# Iteration 900: Probability = 0.11046527326107025
# Iteration 0: Probability = 0.12073904275894165
# Iteration 100: Probability = 0.12046007066965103
# Iteration 200: Probability = 0.11966780573129654
# Iteration 300: Probability = 0.12052278220653534
# Iteration 400: Probability = 0.1201302781701088
# Iteration 500: Probability = 0.11905577033758163
# Iteration 600: Probability = 0.11830220371484756
# Iteration 700: Probability = 0.11796271800994873
# Iteration 800: Probability = 0.11734585464000702
# Iteration 900: Probability = 0.11826567351818085
# Iteration 0: Probability = 0.11998994648456573
# Iteration 100: Probability = 0.11863070726394653
# Iteration 200: Probability = 0.11857873201370239
# Iteration 300: Probability = 0.1185685396194458
# Iteration 400: Probability = 0.11892493069171906
# Iteration 500: Probability = 0.11881963908672333
# Iteration 600: Probability = 0.11844508349895477
# Iteration 700: Probability = 0.11713466793298721
# Iteration 800: Probability = 0.11764433234930038
# Iteration 900: Probability = 0.11759308725595474
# Iteration 0: Probability = 0.1597091406583786
# Iteration 100: Probability = 0.12550662457942963
# Iteration 200: Probability = 0.1251867115497589
# Iteration 300: Probability = 0.12493044137954712
# Iteration 400: Probability = 0.12378500401973724
# Iteration 500: Probability = 0.12431950867176056
# Iteration 600: Probability = 0.12373274564743042
# Iteration 700: Probability = 0.1227388009428978
# Iteration 800: Probability = 0.12227378785610199
# Iteration 900: Probability = 0.12202246487140656
# Iteration 0: Probability = 0.2000124752521515
# Iteration 100: Probability = 0.12120342254638672
# Iteration 200: Probability = 0.12061655521392822
# Iteration 300: Probability = 0.12003383785486221
# Iteration 400: Probability = 0.11909870058298111
# Iteration 500: Probability = 0.11890070140361786
# Iteration 600: Probability = 0.11967746168375015
# Iteration 700: Probability = 0.11854597181081772
# Iteration 800: Probability = 0.11800333112478256
# Iteration 900: Probability = 0.11732401698827744
# Iteration 0: Probability = 0.11214479058980942
# Iteration 100: Probability = 0.11213523149490356
# Iteration 200: Probability = 0.11190545558929443
# Iteration 300: Probability = 0.1122175082564354
# Iteration 400: Probability = 0.11219777911901474
# Iteration 500: Probability = 0.11178213357925415
# Iteration 600: Probability = 0.11170296370983124
# Iteration 700: Probability = 0.11176605522632599
# Iteration 800: Probability = 0.11135463416576385
# Iteration 900: Probability = 0.11181007325649261
# Iteration 0: Probability = 0.11391760408878326
# Iteration 100: Probability = 0.11341670900583267
# Iteration 200: Probability = 0.11328842490911484
# Iteration 300: Probability = 0.11336226761341095
# Iteration 400: Probability = 0.1128232479095459
# Iteration 500: Probability = 0.11279650777578354
# Iteration 600: Probability = 0.11256365478038788
# Iteration 700: Probability = 0.11226139217615128
# Iteration 800: Probability = 0.11197619140148163
# Iteration 900: Probability = 0.11187704652547836
# Iteration 0: Probability = 0.11983201652765274
# Iteration 100: Probability = 0.11927517503499985
# Iteration 200: Probability = 0.11916404962539673
# Iteration 300: Probability = 0.11857476085424423
# Iteration 400: Probability = 0.11798970401287079
# Iteration 500: Probability = 0.11785624921321869
# Iteration 600: Probability = 0.11804565042257309
# Iteration 700: Probability = 0.11757375299930573
# Iteration 800: Probability = 0.11743219196796417
# Iteration 900: Probability = 0.11740758270025253
# Iteration 0: Probability = 0.10762909799814224
# Iteration 100: Probability = 0.10748782008886337
# Iteration 200: Probability = 0.10736334323883057
# Iteration 300: Probability = 0.10711640119552612
# Iteration 400: Probability = 0.10701031982898712
# Iteration 500: Probability = 0.10653557628393173
# Iteration 600: Probability = 0.1065635085105896
# Iteration 700: Probability = 0.10650324821472168
# Iteration 800: Probability = 0.10668066889047623
# Iteration 900: Probability = 0.1064903512597084
# After Adversarial Training - Clean Acc: 30.0%, Adversarial Acc: 17.0%

# %%
# Evaluate the model's performance on adversarial examples
def evaluate_performance(model, data_loader):
    model.eval()
    correct, total, adv_correct, adv_total = 0, 0, 0, 0
    for data, labels in data_loader:
        data, labels = data.to(device), labels.to(device)
        outputs = model(data)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

        # Generate adversarial examples
        adv_data, _, _ = simba_single(model, data, labels)
        adv_outputs = model(adv_data)
        _, adv_predicted = torch.max(adv_outputs.data, 1)
        adv_total += labels.size(0)
        adv_correct += (adv_predicted == labels).sum().item()

    clean_acc = 100 * correct / total
    adv_acc = 100 * adv_correct / adv_total
    return clean_acc, adv_acc

# Training settings
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = SimpleLSTM().to(device)
optimizer = optim.Adam(model.parameters(), lr=0.01)
loss_fn = nn.CrossEntropyLoss()

# Create data
data, labels = create_dataset()
dataset = TensorDataset(data, labels)
loader = DataLoader(dataset, batch_size=10, shuffle=True)

# Evaluate before adversarial training
clean_acc_before, adv_acc_before = evaluate_performance(model, loader)
print(f'Before Adversarial Training - Clean Acc: {clean_acc_before}%, Adversarial Acc: {adv_acc_before}%')

# Adversarial training
for epoch in range(5):  # Short training for demonstration
    model.train()
    for inputs, targets in loader:
        inputs, targets = inputs.to(device), targets.to(device)

        # Regular training
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = loss_fn(outputs, targets)
        loss.backward()
        optimizer.step()

        # Adversarial training
        adv_inputs, _, _ = simba_single(model, inputs, targets)
        optimizer.zero_grad()
        adv_outputs = model(adv_inputs)
        adv_loss = loss_fn(adv_outputs, targets)
        adv_loss.backward()
        optimizer.step()

    print(f'Epoch {epoch + 1}, Loss: {loss.item()}, Adv Loss: {adv_loss.item()}')

# Evaluate after adversarial training
clean_acc_after, adv_acc_after = evaluate_performance(model, loader)
print(f'After Adversarial Training - Clean Acc: {clean_acc_after}%, Adversarial Acc: {adv_acc_after}%')
# Out:
# Iteration 0: Probability = 0.4997364580631256
# Iteration 100: Probability = 0.4995090067386627
# Iteration 200: Probability = 0.4993008077144623
# Iteration 300: Probability = 0.499114453792572
# Iteration 400: Probability = 0.49895787239074707
# Iteration 500: Probability = 0.4988992214202881
# Iteration 600: Probability = 0.4988992214202881
# Iteration 700: Probability = 0.4988992214202881
# Iteration 800: Probability = 0.4988992214202881
# Iteration 900: Probability = 0.4988992214202881
# Iteration 0: Probability = 0.49907422065734863
# Iteration 100: Probability = 0.4986141324043274
# Iteration 200: Probability = 0.4982624053955078
# Iteration 300: Probability = 0.49804526567459106
# Iteration 400: Probability = 0.4978368282318115
# Iteration 500: Probability = 0.4976484179496765
# Iteration 600: Probability = 0.49764758348464966
# Iteration 700: Probability = 0.49764758348464966
# Iteration 800: Probability = 0.49764758348464966
# Iteration 900: Probability = 0.49764758348464966
# Iteration 0: Probability = 0.4845871329307556
# Iteration 100: Probability = 0.4841333329677582
# Iteration 200: Probability = 0.4837978780269623
# Iteration 300: Probability = 0.4835294783115387
# Iteration 400: Probability = 0.48333635926246643
# Iteration 500: Probability = 0.4831671118736267
# Iteration 600: Probability = 0.48316293954849243
# Iteration 700: Probability = 0.48316293954849243
# Iteration 800: Probability = 0.48316293954849243
# Iteration 900: Probability = 0.48316293954849243
# Iteration 0: Probability = 0.49955058097839355
# Iteration 100: Probability = 0.4989164471626282
# Iteration 200: Probability = 0.4984773099422455
# Iteration 300: Probability = 0.4982267916202545
# Iteration 400: Probability = 0.49800562858581543
# Iteration 500: Probability = 0.49784407019615173
# Iteration 600: Probability = 0.49784407019615173
# Iteration 700: Probability = 0.49784407019615173
# Iteration 800: Probability = 0.49784407019615173
# Iteration 900: Probability = 0.49784407019615173
# Iteration 0: Probability = 0.46946167945861816
# Iteration 100: Probability = 0.46908140182495117
# Iteration 200: Probability = 0.4688049256801605
# Iteration 300: Probability = 0.468549907207489
# Iteration 400: Probability = 0.46831947565078735
# Iteration 500: Probability = 0.46810847520828247
# Iteration 600: Probability = 0.46810847520828247
# Iteration 700: Probability = 0.46810847520828247
# Iteration 800: Probability = 0.46810847520828247
# Iteration 900: Probability = 0.46810847520828247
# Iteration 0: Probability = 0.4538937211036682
# Iteration 100: Probability = 0.45350146293640137
# Iteration 200: Probability = 0.4531322419643402
# Iteration 300: Probability = 0.452949196100235
# Iteration 400: Probability = 0.452847957611084
# Iteration 500: Probability = 0.45277270674705505
# Iteration 600: Probability = 0.45277053117752075
# Iteration 700: Probability = 0.45277053117752075
# Iteration 800: Probability = 0.45277053117752075
# Iteration 900: Probability = 0.45277053117752075
# Iteration 0: Probability = 0.5146350264549255
# Iteration 100: Probability = 0.5140818357467651
# Iteration 200: Probability = 0.5136738419532776
# Iteration 300: Probability = 0.5133558511734009
# Iteration 400: Probability = 0.5131320953369141
# Iteration 500: Probability = 0.5129575729370117
# Iteration 600: Probability = 0.5129544734954834
# Iteration 700: Probability = 0.5129544734954834
# Iteration 800: Probability = 0.5129544734954834
# Iteration 900: Probability = 0.5129544734954834
# Iteration 0: Probability = 0.49929898977279663
# Iteration 100: Probability = 0.49879828095436096
# Iteration 200: Probability = 0.4983469843864441
# Iteration 300: Probability = 0.4980675280094147
# Iteration 400: Probability = 0.4978434443473816
# Iteration 500: Probability = 0.4976463317871094
# Iteration 600: Probability = 0.4976462721824646
# Iteration 700: Probability = 0.4976462721824646
# Iteration 800: Probability = 0.4976462721824646
# Iteration 900: Probability = 0.4976462721824646
# Iteration 0: Probability = 0.4838826656341553
# Iteration 100: Probability = 0.4835285544395447
# Iteration 200: Probability = 0.48325666785240173
# Iteration 300: Probability = 0.48302245140075684
# Iteration 400: Probability = 0.48288241028785706
# Iteration 500: Probability = 0.4827921390533447
# Iteration 600: Probability = 0.48279207944869995
# Iteration 700: Probability = 0.48279207944869995
# Iteration 800: Probability = 0.48279207944869995
# Iteration 900: Probability = 0.48279207944869995
# Iteration 0: Probability = 0.49927252531051636
# Iteration 100: Probability = 0.4988737106323242
# Iteration 200: Probability = 0.4984884262084961
# Iteration 300: Probability = 0.49816131591796875
# Iteration 400: Probability = 0.49793004989624023
# Iteration 500: Probability = 0.49772900342941284
# Iteration 600: Probability = 0.49772900342941284
# Iteration 700: Probability = 0.49772900342941284
# Iteration 800: Probability = 0.49772900342941284
# Iteration 900: Probability = 0.49772900342941284
# Before Adversarial Training - Clean Acc: 44.0%, Adversarial Acc: 44.0%
# Iteration 0: Probability = 0.4996936321258545
# Iteration 100: Probability = 0.49920088052749634
# Iteration 200: Probability = 0.49878281354904175
# Iteration 300: Probability = 0.4984581470489502
# Iteration 400: Probability = 0.4981895089149475
# Iteration 500: Probability = 0.4980006814002991
# Iteration 600: Probability = 0.4980006814002991
# Iteration 700: Probability = 0.4980006814002991
# Iteration 800: Probability = 0.4980006814002991
# Iteration 900: Probability = 0.4980006814002991
# Iteration 0: Probability = 0.4976584315299988
# Iteration 100: Probability = 0.496798038482666
# Iteration 200: Probability = 0.4961118698120117
# Iteration 300: Probability = 0.49546870589256287
# Iteration 400: Probability = 0.49485570192337036
# Iteration 500: Probability = 0.49443501234054565
# Iteration 600: Probability = 0.49443498253822327
# Iteration 700: Probability = 0.49443498253822327
# Iteration 800: Probability = 0.49443498253822327
# Iteration 900: Probability = 0.49443498253822327
# Iteration 0: Probability = 0.5196837186813354
# Iteration 100: Probability = 0.5181521773338318
# Iteration 200: Probability = 0.5170120000839233
# Iteration 300: Probability = 0.5162172913551331
# Iteration 400: Probability = 0.515762209892273
# Iteration 500: Probability = 0.5154725313186646
# Iteration 600: Probability = 0.5154724717140198
# Iteration 700: Probability = 0.5154724717140198
# Iteration 800: Probability = 0.5154724717140198
# Iteration 900: Probability = 0.5154724717140198
# Iteration 0: Probability = 0.49753063917160034
# Iteration 100: Probability = 0.49600544571876526
# Iteration 200: Probability = 0.49485093355178833
# Iteration 300: Probability = 0.49386081099510193
# Iteration 400: Probability = 0.4929893910884857
# Iteration 500: Probability = 0.49228206276893616
# Iteration 600: Probability = 0.4922820031642914
# Iteration 700: Probability = 0.4922820031642914
# Iteration 800: Probability = 0.4922820031642914
# Iteration 900: Probability = 0.4922820031642914
# Iteration 0: Probability = 0.5725831389427185
# Iteration 100: Probability = 0.5716493725776672
# Iteration 200: Probability = 0.5707149505615234
# Iteration 300: Probability = 0.5697793960571289
# Iteration 400: Probability = 0.5693100690841675
# Iteration 500: Probability = 0.5691995620727539
# Iteration 600: Probability = 0.5691994428634644
# Iteration 700: Probability = 0.5691994428634644
# Iteration 800: Probability = 0.5691994428634644
# Iteration 900: Probability = 0.5691994428634644
# Iteration 0: Probability = 0.4993100166320801
# Iteration 100: Probability = 0.49887770414352417
# Iteration 200: Probability = 0.4984918534755707
# Iteration 300: Probability = 0.49817022681236267
# Iteration 400: Probability = 0.49801501631736755
# Iteration 500: Probability = 0.49788182973861694
# Iteration 600: Probability = 0.49788179993629456
# Iteration 700: Probability = 0.49788179993629456
# Iteration 800: Probability = 0.49788179993629456
# Iteration 900: Probability = 0.49788179993629456
# Iteration 0: Probability = 0.5958861708641052
# Iteration 100: Probability = 0.5953902006149292
# Iteration 200: Probability = 0.5949167013168335
# Iteration 300: Probability = 0.5945306420326233
# Iteration 400: Probability = 0.5942290425300598
# Iteration 500: Probability = 0.5939776301383972
# Iteration 600: Probability = 0.5939654111862183
# Iteration 700: Probability = 0.5939654111862183
# Iteration 800: Probability = 0.5939654111862183
# Iteration 900: Probability = 0.5939654111862183
# Iteration 0: Probability = 0.49841079115867615
# Iteration 100: Probability = 0.4979013502597809
# Iteration 200: Probability = 0.4975054860115051
# Iteration 300: Probability = 0.49717503786087036
# Iteration 400: Probability = 0.4969005584716797
# Iteration 500: Probability = 0.4967038035392761
# Iteration 600: Probability = 0.4967038035392761
# Iteration 700: Probability = 0.4967038035392761
# Iteration 800: Probability = 0.4967038035392761
# Iteration 900: Probability = 0.4967038035392761
# Iteration 0: Probability = 0.4702867567539215
# Iteration 100: Probability = 0.46979913115501404
# Iteration 200: Probability = 0.4693896174430847
# Iteration 300: Probability = 0.46907559037208557
# Iteration 400: Probability = 0.46882686018943787
# Iteration 500: Probability = 0.4686797261238098
# Iteration 600: Probability = 0.4686797261238098
# Iteration 700: Probability = 0.4686797261238098
# Iteration 800: Probability = 0.4686797261238098
# Iteration 900: Probability = 0.4686797261238098
# Iteration 0: Probability = 0.4803902208805084
# Iteration 100: Probability = 0.4800899922847748
# Iteration 200: Probability = 0.4798421859741211
# Iteration 300: Probability = 0.4796358644962311
# Iteration 400: Probability = 0.47945767641067505
# Iteration 500: Probability = 0.4793550968170166
# Iteration 600: Probability = 0.47933587431907654
# Iteration 700: Probability = 0.47933587431907654
# Iteration 800: Probability = 0.47933587431907654
# Iteration 900: Probability = 0.47933587431907654
# Epoch 1, Loss: 0.771349310874939, Adv Loss: 0.7530428171157837
# Iteration 0: Probability = 0.536408543586731
# Iteration 100: Probability = 0.5363505482673645
# Iteration 200: Probability = 0.536317765712738
# Iteration 300: Probability = 0.5363059639930725
# Iteration 400: Probability = 0.5362952947616577
# Iteration 500: Probability = 0.5362915396690369
# Iteration 600: Probability = 0.5362915396690369
# Iteration 700: Probability = 0.5362915396690369
# Iteration 800: Probability = 0.5362915396690369
# Iteration 900: Probability = 0.5362915396690369
# Iteration 0: Probability = 0.49950748682022095
# Iteration 100: Probability = 0.49928969144821167
# Iteration 200: Probability = 0.4991309642791748
# Iteration 300: Probability = 0.498983234167099
# Iteration 400: Probability = 0.49887117743492126
# Iteration 500: Probability = 0.498828649520874
# Iteration 600: Probability = 0.49882858991622925
# Iteration 700: Probability = 0.49882858991622925
# Iteration 800: Probability = 0.49882858991622925
# Iteration 900: Probability = 0.49882858991622925
# Iteration 0: Probability = 0.49318012595176697
# Iteration 100: Probability = 0.4929850101470947
# Iteration 200: Probability = 0.4928158223628998
# Iteration 300: Probability = 0.4926699995994568
# Iteration 400: Probability = 0.4925546646118164
# Iteration 500: Probability = 0.49250873923301697
# Iteration 600: Probability = 0.49250873923301697
# Iteration 700: Probability = 0.49250873923301697
# Iteration 800: Probability = 0.49250873923301697
# Iteration 900: Probability = 0.49250873923301697
# Iteration 0: Probability = 0.49976372718811035
# Iteration 100: Probability = 0.49968862533569336
# Iteration 200: Probability = 0.4996507167816162
# Iteration 300: Probability = 0.49963459372520447
# Iteration 400: Probability = 0.49962276220321655
# Iteration 500: Probability = 0.49961233139038086
# Iteration 600: Probability = 0.49961233139038086
# Iteration 700: Probability = 0.49961233139038086
# Iteration 800: Probability = 0.49961233139038086
# Iteration 900: Probability = 0.49961233139038086
# Iteration 0: Probability = 0.4999029040336609
# Iteration 100: Probability = 0.4998667240142822
# Iteration 200: Probability = 0.4998481273651123
# Iteration 300: Probability = 0.4998367428779602
# Iteration 400: Probability = 0.49982619285583496
# Iteration 500: Probability = 0.4998161792755127
# Iteration 600: Probability = 0.4998161196708679
# Iteration 700: Probability = 0.4998161196708679
# Iteration 800: Probability = 0.4998161196708679
# Iteration 900: Probability = 0.4998161196708679
# Iteration 0: Probability = 0.5002001523971558
# Iteration 100: Probability = 0.5001188516616821
# Iteration 200: Probability = 0.5000550150871277
# Iteration 300: Probability = 0.5000292062759399
# Iteration 400: Probability = 0.5000050663948059
# Iteration 500: Probability = 0.49998021125793457
# Iteration 600: Probability = 0.4999801516532898
# Iteration 700: Probability = 0.4999801516532898
# Iteration 800: Probability = 0.4999801516532898
# Iteration 900: Probability = 0.4999801516532898
# Iteration 0: Probability = 0.4999372065067291
# Iteration 100: Probability = 0.49990591406822205
# Iteration 200: Probability = 0.4998933672904968
# Iteration 300: Probability = 0.49988141655921936
# Iteration 400: Probability = 0.49987292289733887
# Iteration 500: Probability = 0.4998651444911957
# Iteration 600: Probability = 0.4998651444911957
# Iteration 700: Probability = 0.4998651444911957
# Iteration 800: Probability = 0.4998651444911957
# Iteration 900: Probability = 0.4998651444911957
# Iteration 0: Probability = 0.4983324408531189
# Iteration 100: Probability = 0.4981650412082672
# Iteration 200: Probability = 0.4979840815067291
# Iteration 300: Probability = 0.4978318214416504
# Iteration 400: Probability = 0.4977395534515381
# Iteration 500: Probability = 0.4976716935634613
# Iteration 600: Probability = 0.4976716935634613
# Iteration 700: Probability = 0.4976716637611389
# Iteration 800: Probability = 0.4976716637611389
# Iteration 900: Probability = 0.4976716637611389
# Iteration 0: Probability = 0.4984564781188965
# Iteration 100: Probability = 0.498439222574234
# Iteration 200: Probability = 0.49842411279678345
# Iteration 300: Probability = 0.49840670824050903
# Iteration 400: Probability = 0.4983915388584137
# Iteration 500: Probability = 0.49838510155677795
# Iteration 600: Probability = 0.49838510155677795
# Iteration 700: Probability = 0.49838510155677795
# Iteration 800: Probability = 0.49838510155677795
# Iteration 900: Probability = 0.49838510155677795
# Iteration 0: Probability = 0.49949055910110474
# Iteration 100: Probability = 0.4993534982204437
# Iteration 200: Probability = 0.499213844537735
# Iteration 300: Probability = 0.4990730881690979
# Iteration 400: Probability = 0.49897274374961853
# Iteration 500: Probability = 0.4988937973976135
# Iteration 600: Probability = 0.4988928735256195
# Iteration 700: Probability = 0.4988928735256195
# Iteration 800: Probability = 0.4988928735256195
# Iteration 900: Probability = 0.4988928735256195
# Epoch 2, Loss: 0.6936932802200317, Adv Loss: 0.6944720149040222
# Iteration 0: Probability = 0.5027064085006714
# Iteration 100: Probability = 0.5024830102920532
# Iteration 200: Probability = 0.5023598074913025
# Iteration 300: Probability = 0.5023288130760193
# Iteration 400: Probability = 0.5023097395896912
# Iteration 500: Probability = 0.5022984147071838
# Iteration 600: Probability = 0.5022984147071838
# Iteration 700: Probability = 0.5022984147071838
# Iteration 800: Probability = 0.5022984147071838
# Iteration 900: Probability = 0.5022984147071838
# Iteration 0: Probability = 0.49972501397132874
# Iteration 100: Probability = 0.499467134475708
# Iteration 200: Probability = 0.4992554783821106
# Iteration 300: Probability = 0.49903449416160583
# Iteration 400: Probability = 0.498929500579834
# Iteration 500: Probability = 0.4988424777984619
# Iteration 600: Probability = 0.4988424777984619
# Iteration 700: Probability = 0.49884241819381714
# Iteration 800: Probability = 0.49884241819381714
# Iteration 900: Probability = 0.49884241819381714
# Iteration 0: Probability = 0.5097220540046692
# Iteration 100: Probability = 0.5093272924423218
# Iteration 200: Probability = 0.509024977684021
# Iteration 300: Probability = 0.5087763071060181
# Iteration 400: Probability = 0.5086706876754761
# Iteration 500: Probability = 0.5086298584938049
# Iteration 600: Probability = 0.5086295008659363
# Iteration 700: Probability = 0.5086295008659363
# Iteration 800: Probability = 0.5086295008659363
# Iteration 900: Probability = 0.5086295008659363
# Iteration 0: Probability = 0.4927681088447571
# Iteration 100: Probability = 0.4926910996437073
# Iteration 200: Probability = 0.4926289916038513
# Iteration 300: Probability = 0.4925924241542816
# Iteration 400: Probability = 0.4925610423088074
# Iteration 500: Probability = 0.49252834916114807
# Iteration 600: Probability = 0.49252834916114807
# Iteration 700: Probability = 0.49252834916114807
# Iteration 800: Probability = 0.49252834916114807
# Iteration 900: Probability = 0.49252834916114807
# Iteration 0: Probability = 0.5128259062767029
# Iteration 100: Probability = 0.5126430988311768
# Iteration 200: Probability = 0.5124592185020447
# Iteration 300: Probability = 0.5122739672660828
# Iteration 400: Probability = 0.5120795965194702
# Iteration 500: Probability = 0.5119630098342896
# Iteration 600: Probability = 0.5119630098342896
# Iteration 700: Probability = 0.5119629502296448
# Iteration 800: Probability = 0.5119629502296448
# Iteration 900: Probability = 0.5119629502296448
# Iteration 0: Probability = 0.4981687068939209
# Iteration 100: Probability = 0.4980340898036957
# Iteration 200: Probability = 0.4979143738746643
# Iteration 300: Probability = 0.4978296756744385
# Iteration 400: Probability = 0.49776220321655273
# Iteration 500: Probability = 0.4977339804172516
# Iteration 600: Probability = 0.4977339208126068
# Iteration 700: Probability = 0.4977339208126068
# Iteration 800: Probability = 0.4977339208126068
# Iteration 900: Probability = 0.4977339208126068
# Iteration 0: Probability = 0.4898509085178375
# Iteration 100: Probability = 0.4894532561302185
# Iteration 200: Probability = 0.4892148971557617
# Iteration 300: Probability = 0.48912572860717773
# Iteration 400: Probability = 0.4890371859073639
# Iteration 500: Probability = 0.48894867300987244
# Iteration 600: Probability = 0.48894867300987244
# Iteration 700: Probability = 0.48894867300987244
# Iteration 800: Probability = 0.48894867300987244
# Iteration 900: Probability = 0.48894867300987244
# Iteration 0: Probability = 0.5081063508987427
# Iteration 100: Probability = 0.5076307654380798
# Iteration 200: Probability = 0.5071529150009155
# Iteration 300: Probability = 0.5066754221916199
# Iteration 400: Probability = 0.5065422654151917
# Iteration 500: Probability = 0.5064288377761841
# Iteration 600: Probability = 0.5064288377761841
# Iteration 700: Probability = 0.5064288377761841
# Iteration 800: Probability = 0.5064288377761841
# Iteration 900: Probability = 0.5064288377761841
# Iteration 0: Probability = 0.5194829702377319
# Iteration 100: Probability = 0.5188735127449036
# Iteration 200: Probability = 0.5182458758354187
# Iteration 300: Probability = 0.517756998538971
# Iteration 400: Probability = 0.5173919200897217
# Iteration 500: Probability = 0.5170730352401733
# Iteration 600: Probability = 0.5170730352401733
# Iteration 700: Probability = 0.5170730352401733
# Iteration 800: Probability = 0.5170730352401733
# Iteration 900: Probability = 0.5170730352401733
# Iteration 0: Probability = 0.4991077482700348
# Iteration 100: Probability = 0.49852460622787476
# Iteration 200: Probability = 0.4979243874549866
# Iteration 300: Probability = 0.49741822481155396
# Iteration 400: Probability = 0.4969513416290283
# Iteration 500: Probability = 0.4966045022010803
# Iteration 600: Probability = 0.49660158157348633
# Iteration 700: Probability = 0.49660152196884155
# Iteration 800: Probability = 0.49660152196884155
# Iteration 900: Probability = 0.49660152196884155
# Epoch 3, Loss: 0.6969861388206482, Adv Loss: 0.7020352482795715
# Iteration 0: Probability = 0.5226094126701355
# Iteration 100: Probability = 0.5222263336181641
# Iteration 200: Probability = 0.5220484733581543
# Iteration 300: Probability = 0.5219427347183228
# Iteration 400: Probability = 0.5218507051467896
# Iteration 500: Probability = 0.5217834711074829
# Iteration 600: Probability = 0.5217834711074829
# Iteration 700: Probability = 0.5217834711074829
# Iteration 800: Probability = 0.5217834711074829
# Iteration 900: Probability = 0.5217834711074829
# Iteration 0: Probability = 0.4862149655818939
# Iteration 100: Probability = 0.48583659529685974
# Iteration 200: Probability = 0.4854556620121002
# Iteration 300: Probability = 0.48528069257736206
# Iteration 400: Probability = 0.4852265417575836
# Iteration 500: Probability = 0.485208660364151
# Iteration 600: Probability = 0.48520827293395996
# Iteration 700: Probability = 0.48520827293395996
# Iteration 800: Probability = 0.48520827293395996
# Iteration 900: Probability = 0.48520827293395996
# Iteration 0: Probability = 0.5126376152038574
# Iteration 100: Probability = 0.5121458768844604
# Iteration 200: Probability = 0.5118974447250366
# Iteration 300: Probability = 0.5116997957229614
# Iteration 400: Probability = 0.5116491913795471
# Iteration 500: Probability = 0.5116056203842163
# Iteration 600: Probability = 0.5116056203842163
# Iteration 700: Probability = 0.5116055607795715
# Iteration 800: Probability = 0.5116055607795715
# Iteration 900: Probability = 0.5116055607795715
# Iteration 0: Probability = 0.5126446485519409
# Iteration 100: Probability = 0.5121660232543945
# Iteration 200: Probability = 0.51181960105896
# Iteration 300: Probability = 0.5116212368011475
# Iteration 400: Probability = 0.5114177465438843
# Iteration 500: Probability = 0.5113437175750732
# Iteration 600: Probability = 0.5113415718078613
# Iteration 700: Probability = 0.5113390684127808
# Iteration 800: Probability = 0.5113390684127808
# Iteration 900: Probability = 0.5113390684127808
# Iteration 0: Probability = 0.484518826007843
# Iteration 100: Probability = 0.4844159185886383
# Iteration 200: Probability = 0.48436427116394043
# Iteration 300: Probability = 0.4843253195285797
# Iteration 400: Probability = 0.4842883050441742
# Iteration 500: Probability = 0.4842504858970642
# Iteration 600: Probability = 0.4842504858970642
# Iteration 700: Probability = 0.4842504858970642
# Iteration 800: Probability = 0.4842504858970642
# Iteration 900: Probability = 0.4842504858970642
# Iteration 0: Probability = 0.5118507742881775
# Iteration 100: Probability = 0.5113793611526489
# Iteration 200: Probability = 0.5110380053520203
# Iteration 300: Probability = 0.5109703540802002
# Iteration 400: Probability = 0.5109127163887024
# Iteration 500: Probability = 0.510868489742279
# Iteration 600: Probability = 0.5108684301376343
# Iteration 700: Probability = 0.5108684301376343
# Iteration 800: Probability = 0.5108684301376343
# Iteration 900: Probability = 0.5108684301376343
# Iteration 0: Probability = 0.4859084188938141
# Iteration 100: Probability = 0.48545360565185547
# Iteration 200: Probability = 0.4850974977016449
# Iteration 300: Probability = 0.48484474420547485
# Iteration 400: Probability = 0.48475027084350586
# Iteration 500: Probability = 0.48473644256591797
# Iteration 600: Probability = 0.4847363531589508
# Iteration 700: Probability = 0.4847363531589508
# Iteration 800: Probability = 0.48473629355430603
# Iteration 900: Probability = 0.48473629355430603
# Iteration 0: Probability = 0.5117306709289551
# Iteration 100: Probability = 0.5112623572349548
# Iteration 200: Probability = 0.5107635259628296
# Iteration 300: Probability = 0.5102308392524719
# Iteration 400: Probability = 0.5102009177207947
# Iteration 500: Probability = 0.510197639465332
# Iteration 600: Probability = 0.510197639465332
# Iteration 700: Probability = 0.5101975798606873
# Iteration 800: Probability = 0.5101975202560425
# Iteration 900: Probability = 0.5101975202560425
# Iteration 0: Probability = 0.49855107069015503
# Iteration 100: Probability = 0.49809184670448303
# Iteration 200: Probability = 0.49750176072120667
# Iteration 300: Probability = 0.49691468477249146
# Iteration 400: Probability = 0.4966723918914795
# Iteration 500: Probability = 0.4966610074043274
# Iteration 600: Probability = 0.4966604709625244
# Iteration 700: Probability = 0.4966604709625244
# Iteration 800: Probability = 0.4966604709625244
# Iteration 900: Probability = 0.4966604709625244
# Iteration 0: Probability = 0.5278461575508118
# Iteration 100: Probability = 0.5274553894996643
# Iteration 200: Probability = 0.5270388126373291
# Iteration 300: Probability = 0.5266193151473999
# Iteration 400: Probability = 0.5265485644340515
# Iteration 500: Probability = 0.5264962911605835
# Iteration 600: Probability = 0.5264912247657776
# Iteration 700: Probability = 0.5264877080917358
# Iteration 800: Probability = 0.5264831781387329
# Iteration 900: Probability = 0.5264805555343628
# Epoch 4, Loss: 0.6518533825874329, Adv Loss: 0.6404653787612915
# Iteration 0: Probability = 0.4750119745731354
# Iteration 100: Probability = 0.4749792516231537
# Iteration 200: Probability = 0.47495317459106445
# Iteration 300: Probability = 0.47493094205856323
# Iteration 400: Probability = 0.47491273283958435
# Iteration 500: Probability = 0.4748978614807129
# Iteration 600: Probability = 0.4748978614807129
# Iteration 700: Probability = 0.4748978614807129
# Iteration 800: Probability = 0.4748978614807129
# Iteration 900: Probability = 0.4748978614807129
# Iteration 0: Probability = 0.5186262726783752
# Iteration 100: Probability = 0.5185927152633667
# Iteration 200: Probability = 0.5185667872428894
# Iteration 300: Probability = 0.5185414552688599
# Iteration 400: Probability = 0.5185140371322632
# Iteration 500: Probability = 0.5184836387634277
# Iteration 600: Probability = 0.5184835195541382
# Iteration 700: Probability = 0.5184835195541382
# Iteration 800: Probability = 0.5184835195541382
# Iteration 900: Probability = 0.5184835195541382
# Iteration 0: Probability = 0.5087786912918091
# Iteration 100: Probability = 0.5075194835662842
# Iteration 200: Probability = 0.5064438581466675
# Iteration 300: Probability = 0.5053378939628601
# Iteration 400: Probability = 0.5051952004432678
# Iteration 500: Probability = 0.5051877498626709
# Iteration 600: Probability = 0.5051877498626709
# Iteration 700: Probability = 0.5051876902580261
# Iteration 800: Probability = 0.5051876902580261
# Iteration 900: Probability = 0.5051876902580261
# Iteration 0: Probability = 0.4969210624694824
# Iteration 100: Probability = 0.4956420958042145
# Iteration 200: Probability = 0.49488186836242676
# Iteration 300: Probability = 0.4946858286857605
# Iteration 400: Probability = 0.49464210867881775
# Iteration 500: Probability = 0.49460798501968384
# Iteration 600: Probability = 0.4946078658103943
# Iteration 700: Probability = 0.4946078658103943
# Iteration 800: Probability = 0.4946078658103943
# Iteration 900: Probability = 0.4946078658103943
# Iteration 0: Probability = 0.4975224435329437
# Iteration 100: Probability = 0.49647054076194763
# Iteration 200: Probability = 0.4960014820098877
# Iteration 300: Probability = 0.4956296980381012
# Iteration 400: Probability = 0.4955374598503113
# Iteration 500: Probability = 0.4955310821533203
# Iteration 600: Probability = 0.49553102254867554
# Iteration 700: Probability = 0.49553102254867554
# Iteration 800: Probability = 0.49553102254867554
# Iteration 900: Probability = 0.49553102254867554
# Iteration 0: Probability = 0.5209217071533203
# Iteration 100: Probability = 0.5205102562904358
# Iteration 200: Probability = 0.520450234413147
# Iteration 300: Probability = 0.5204259753227234
# Iteration 400: Probability = 0.5204055905342102
# Iteration 500: Probability = 0.5203860998153687
# Iteration 600: Probability = 0.5203860402107239
# Iteration 700: Probability = 0.5203859806060791
# Iteration 800: Probability = 0.5203859806060791
# Iteration 900: Probability = 0.5203859806060791
# Iteration 0: Probability = 0.48412418365478516
# Iteration 100: Probability = 0.4831017851829529
# Iteration 200: Probability = 0.4820289611816406
# Iteration 300: Probability = 0.4814912676811218
# Iteration 400: Probability = 0.4814474582672119
# Iteration 500: Probability = 0.4814172685146332
# Iteration 600: Probability = 0.4814172387123108
# Iteration 700: Probability = 0.4814172387123108
# Iteration 800: Probability = 0.4814172387123108
# Iteration 900: Probability = 0.4814172387123108
# Iteration 0: Probability = 0.5263356566429138
# Iteration 100: Probability = 0.5255664587020874
# Iteration 200: Probability = 0.5247295498847961
# Iteration 300: Probability = 0.524265706539154
# Iteration 400: Probability = 0.5241916179656982
# Iteration 500: Probability = 0.5241760015487671
# Iteration 600: Probability = 0.5241760015487671
# Iteration 700: Probability = 0.5241760015487671
# Iteration 800: Probability = 0.5241760015487671
# Iteration 900: Probability = 0.5241760015487671
# Iteration 0: Probability = 0.5090552568435669
# Iteration 100: Probability = 0.5082852244377136
# Iteration 200: Probability = 0.5074656009674072
# Iteration 300: Probability = 0.5069066882133484
# Iteration 400: Probability = 0.5064604878425598
# Iteration 500: Probability = 0.5064114332199097
# Iteration 600: Probability = 0.5064104199409485
# Iteration 700: Probability = 0.5064104199409485
# Iteration 800: Probability = 0.5064104199409485
# Iteration 900: Probability = 0.5064104199409485
# Iteration 0: Probability = 0.5161332488059998
# Iteration 100: Probability = 0.5149372816085815
# Iteration 200: Probability = 0.513638973236084
# Iteration 300: Probability = 0.5125858187675476
# Iteration 400: Probability = 0.5120284557342529
# Iteration 500: Probability = 0.5118461847305298
# Iteration 600: Probability = 0.5118461847305298
# Iteration 700: Probability = 0.5118461847305298
# Iteration 800: Probability = 0.5118461847305298
# Iteration 900: Probability = 0.5118461847305298
# Epoch 5, Loss: 0.6348953247070312, Adv Loss: 0.6281849145889282
# Iteration 0: Probability = 0.5145524740219116
# Iteration 100: Probability = 0.5132361650466919
# Iteration 200: Probability = 0.5116292238235474
# Iteration 300: Probability = 0.5098477602005005
# Iteration 400: Probability = 0.5091537237167358
# Iteration 500: Probability = 0.5090831518173218
# Iteration 600: Probability = 0.509083092212677
# Iteration 700: Probability = 0.509083092212677
# Iteration 800: Probability = 0.509083092212677
# Iteration 900: Probability = 0.509083092212677
# Iteration 0: Probability = 0.49772733449935913
# Iteration 100: Probability = 0.49650654196739197
# Iteration 200: Probability = 0.4958432614803314
# Iteration 300: Probability = 0.49573978781700134
# Iteration 400: Probability = 0.4956415295600891
# Iteration 500: Probability = 0.49556413292884827
# Iteration 600: Probability = 0.4955640733242035
# Iteration 700: Probability = 0.4955640733242035
# Iteration 800: Probability = 0.4955640733242035
# Iteration 900: Probability = 0.4955640733242035
# Iteration 0: Probability = 0.4930708408355713
# Iteration 100: Probability = 0.49257975816726685
# Iteration 200: Probability = 0.49191299080848694
# Iteration 300: Probability = 0.4912436902523041
# Iteration 400: Probability = 0.4906911849975586
# Iteration 500: Probability = 0.49060550332069397
# Iteration 600: Probability = 0.4905985891819
# Iteration 700: Probability = 0.4905985891819
# Iteration 800: Probability = 0.4905985891819
# Iteration 900: Probability = 0.4905985891819
# Iteration 0: Probability = 0.49645256996154785
# Iteration 100: Probability = 0.49452081322669983
# Iteration 200: Probability = 0.4931252598762512
# Iteration 300: Probability = 0.4928823411464691
# Iteration 400: Probability = 0.4927721619606018
# Iteration 500: Probability = 0.4926888942718506
# Iteration 600: Probability = 0.492687463760376
# Iteration 700: Probability = 0.492687463760376
# Iteration 800: Probability = 0.4926874041557312
# Iteration 900: Probability = 0.4926874041557312
# Iteration 0: Probability = 0.4999222755432129
# Iteration 100: Probability = 0.4993906021118164
# Iteration 200: Probability = 0.4987892210483551
# Iteration 300: Probability = 0.4981148838996887
# Iteration 400: Probability = 0.4980344772338867
# Iteration 500: Probability = 0.4979916512966156
# Iteration 600: Probability = 0.4979916512966156
# Iteration 700: Probability = 0.4979916512966156
# Iteration 800: Probability = 0.4979916512966156
# Iteration 900: Probability = 0.4979916512966156
# Iteration 0: Probability = 0.4992145597934723
# Iteration 100: Probability = 0.49915313720703125
# Iteration 200: Probability = 0.4991011619567871
# Iteration 300: Probability = 0.4990457594394684
# Iteration 400: Probability = 0.49901920557022095
# Iteration 500: Probability = 0.49901166558265686
# Iteration 600: Probability = 0.4990116059780121
# Iteration 700: Probability = 0.4990116059780121
# Iteration 800: Probability = 0.4990116059780121
# Iteration 900: Probability = 0.4990116059780121
# Iteration 0: Probability = 0.4604889750480652
# Iteration 100: Probability = 0.45940881967544556
# Iteration 200: Probability = 0.4590134620666504
# Iteration 300: Probability = 0.45893245935440063
# Iteration 400: Probability = 0.4588684141635895
# Iteration 500: Probability = 0.45881158113479614
# Iteration 600: Probability = 0.45881158113479614
# Iteration 700: Probability = 0.45881158113479614
# Iteration 800: Probability = 0.45881158113479614
# Iteration 900: Probability = 0.45881158113479614
# Iteration 0: Probability = 0.5298231840133667
# Iteration 100: Probability = 0.5291041135787964
# Iteration 200: Probability = 0.5284520387649536
# Iteration 300: Probability = 0.5277432203292847
# Iteration 400: Probability = 0.5276280641555786
# Iteration 500: Probability = 0.5275290608406067
# Iteration 600: Probability = 0.5275290608406067
# Iteration 700: Probability = 0.5275290608406067
# Iteration 800: Probability = 0.5275290608406067
# Iteration 900: Probability = 0.5275290608406067
# Iteration 0: Probability = 0.5311660170555115
# Iteration 100: Probability = 0.5291784405708313
# Iteration 200: Probability = 0.5276268720626831
# Iteration 300: Probability = 0.5263727307319641
# Iteration 400: Probability = 0.5260874032974243
# Iteration 500: Probability = 0.5260194540023804
# Iteration 600: Probability = 0.5260194540023804
# Iteration 700: Probability = 0.5260194540023804
# Iteration 800: Probability = 0.5260194540023804
# Iteration 900: Probability = 0.5260194540023804
# Iteration 0: Probability = 0.5433639287948608
# Iteration 100: Probability = 0.5418038964271545
# Iteration 200: Probability = 0.5408908724784851
# Iteration 300: Probability = 0.5403234362602234
# Iteration 400: Probability = 0.5401791930198669
# Iteration 500: Probability = 0.5400554537773132
# Iteration 600: Probability = 0.5400553941726685
# Iteration 700: Probability = 0.5400553345680237
# Iteration 800: Probability = 0.5400553345680237
# Iteration 900: Probability = 0.5400553345680237
# After Adversarial Training - Clean Acc: 59.0%, Adversarial Acc: 60.0%
